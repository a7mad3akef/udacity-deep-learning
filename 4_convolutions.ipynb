# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
 
    # op = tf.nn.conv2d(input, filter, strides=[1, 1, 1, 1], padding='VALID')
    
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.602304
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.034830
# Minibatch accuracy: 18.8%
# Validation accuracy: 37.5%
# Minibatch loss at step 100: 2.026174
# Minibatch accuracy: 43.8%
# Validation accuracy: 61.1%
# Minibatch loss at step 150: 0.449739
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.8%
# Minibatch loss at step 200: 0.654676
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.3%
# Minibatch loss at step 250: 0.644487
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 300: 0.742131
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 350: 1.010301
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.714343
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 450: 0.638668
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.3%
# Minibatch loss at step 500: 0.578070
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 550: 1.029243
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 600: 1.006317
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 650: 1.044078
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 700: 0.932747
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 750: 0.733297
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 800: 0.700234
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 850: 0.882041
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 900: 0.328788
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 950: 0.264714
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 0.717292
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Test accuracy: 88.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.416828
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.978653
# Minibatch accuracy: 12.5%
# Validation accuracy: 48.1%
# Minibatch loss at step 100: 2.096568
# Minibatch accuracy: 43.8%
# Validation accuracy: 63.9%
# Minibatch loss at step 150: 0.535946
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 200: 0.571754
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.2%
# Minibatch loss at step 250: 0.624599
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 300: 0.747228
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 350: 0.904871
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 400: 0.634196
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.1%
# Minibatch loss at step 450: 0.602165
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 500: 0.417709
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 550: 0.883404
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 1.089503
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 650: 0.984822
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 700: 0.948652
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.5%
# Minibatch loss at step 750: 0.755129
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 800: 0.524130
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 850: 0.956071
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 900: 0.369563
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 950: 0.243286
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.753516
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Test accuracy: 90.4%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
patch_size = 5
depth1 = 16
depth2 = 32
num_hidden1 = 128
num_hidden2 = 64

# Construct a 7-layer CNN.
# C1: convolutional layer, batch_size x 28 x 28 x 16, convolution size: 5 x 5 x 1 x 16
# S2: sub-sampling layer, batch_size x 14 x 14 x 16
# C3: convolutional layer, batch_size x 10 x 10 x 32, convolution size: 5 x 5 x 6 x 32
# S4: sub-sampling layer, batch_size x 5 x 5 x 32
# C5: convolutional layer, batch_size x 1 x 1 x 128, convolution size: 5 x 5 x 16 x 128
# F6: fully-connected layer, weight size: 128 x 64
# Output layer, weight size: 64 x 10

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth1, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth2, num_hidden1], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden1, num_hidden2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, keep_prob):
    conv = tf.nn.conv2d(data, layer1_weights, [1,1,1,1], 'SAME', name='C1')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    sub = tf.nn.max_pool(hidden, [1,2,2,1], [1,2,2,1], 'SAME', name='S2')
    conv = tf.nn.conv2d(sub, layer2_weights, [1,1,1,1], padding='VALID', name='C3')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    sub = tf.nn.max_pool(hidden, [1,2,2,1], [1,2,2,1], 'SAME', name='S4')
    conv = tf.nn.conv2d(sub, layer3_weights, [1,1,1,1], padding='VALID', name='C5')
    hidden = tf.nn.relu(conv + layer3_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    hidden = tf.nn.dropout(hidden, keep_prob)
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, 0.5)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  #optimizer = tf.train.AdagradOptimizer(0.05).minimize(loss)
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(0.05, global_step, 2000, 0.95)
  optimizer = tf.train.AdagradOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset, 1.0))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

num_steps = 2001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0): 
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 9.646974
# Minibatch accuracy: 10.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 1.437596
# Minibatch accuracy: 74.2%
# Validation accuracy: 71.5%
# Minibatch loss at step 200: 0.963218
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 300: 0.951151
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 400: 0.667795
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.9%
# Minibatch loss at step 500: 0.670396
# Minibatch accuracy: 85.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 600: 0.583856
# Minibatch accuracy: 86.7%
# Validation accuracy: 83.9%
# Minibatch loss at step 700: 0.763911
# Minibatch accuracy: 77.3%
# Validation accuracy: 84.3%
# Minibatch loss at step 800: 0.742893
# Minibatch accuracy: 83.6%
# Validation accuracy: 84.6%
# Minibatch loss at step 900: 0.633013
# Minibatch accuracy: 82.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1000: 0.731646
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 1100: 0.623122
# Minibatch accuracy: 85.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 1200: 0.677821
# Minibatch accuracy: 82.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 1300: 0.689413
# Minibatch accuracy: 80.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 1400: 0.667633
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.0%
# Minibatch loss at step 1500: 0.556491
# Minibatch accuracy: 85.9%
# Validation accuracy: 85.6%
# Minibatch loss at step 1600: 0.624011
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 1700: 0.560854
# Minibatch accuracy: 85.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 1800: 0.472885
# Minibatch accuracy: 85.9%
# Validation accuracy: 86.3%
# Minibatch loss at step 1900: 0.392099
# Minibatch accuracy: 89.1%
# Validation accuracy: 86.8%
# Minibatch loss at step 2000: 0.436148
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.0%
# Test accuracy: 92.2%

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size*image_size )).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10


# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)



# Create some wrappers for simplicity
def conv2d(x, W, b, strides=1):
    # Conv2D wrapper, with bias and relu activation
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    return tf.nn.relu(x)

def maxpool2d(x, k=2):
    # MaxPool2D wrapper
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1],
                          padding='SAME')


# Create model
def conv_net(x, weights, biases, dropout):
    # Reshape input picture
    x = tf.reshape(x, shape=[-1, 28, 28, 1])

    # Convolution Layer
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    # Max Pooling (down-sampling)
    conv1 = maxpool2d(conv1, k=2)

    # Convolution Layer
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    # Max Pooling (down-sampling)
    conv2 = maxpool2d(conv2, k=2)

    # Fully connected layer
    # Reshape conv2 output to fit fully connected layer input
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    # Apply Dropout
    fc1 = tf.nn.dropout(fc1, dropout)

    # Output, class prediction
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out

# Store layers weight & bias
weights = {
    # 5x5 conv, 1 input, 32 outputs
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    # 5x5 conv, 32 inputs, 64 outputs
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    # fully connected, 7*7*64 inputs, 1024 outputs
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    # 1024 inputs, 10 outputs (class prediction)
    'out': tf.Variable(tf.random_normal([1024, n_classes]))
}

biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))
}

# Construct model
pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdagradOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        batch_x = train_dataset[offset:(offset + batch_size), :]
        batch_y = train_labels[offset:(offset + batch_size), :]
        #batch_x, batch_y = mnist.train.next_batch(batch_size)
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y,
                                       keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch loss and accuracy
            loss, acc = sess.run([cost, accuracy], feed_dict={x: batch_x,
                                                              y: batch_y,
                                                              keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + \
                  "{:.6f}".format(loss) + ", Training Accuracy= " + \
                  "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")

    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", \
        sess.run(accuracy, feed_dict={x: test_dataset[:256],
                                      y: test_labels[:256],
                                      keep_prob: 1.}))
# Out:
# Iter 1280, Minibatch Loss= 28926.535156, Training Accuracy= 0.22656
# Iter 2560, Minibatch Loss= 19875.181641, Training Accuracy= 0.39062
# Iter 3840, Minibatch Loss= 17224.863281, Training Accuracy= 0.36719
# Iter 5120, Minibatch Loss= 15351.615234, Training Accuracy= 0.45312
# Iter 6400, Minibatch Loss= 13830.535156, Training Accuracy= 0.49219
# Iter 7680, Minibatch Loss= 13264.578125, Training Accuracy= 0.52344
# Iter 8960, Minibatch Loss= 14935.669922, Training Accuracy= 0.48438
# Iter 10240, Minibatch Loss= 9198.078125, Training Accuracy= 0.61719
# Iter 11520, Minibatch Loss= 14647.126953, Training Accuracy= 0.55469
# Iter 12800, Minibatch Loss= 13227.451172, Training Accuracy= 0.58594
# Iter 14080, Minibatch Loss= 12375.275391, Training Accuracy= 0.56250
# Iter 15360, Minibatch Loss= 10104.502930, Training Accuracy= 0.64844
# Iter 16640, Minibatch Loss= 11703.051758, Training Accuracy= 0.57031
# Iter 17920, Minibatch Loss= 10442.288086, Training Accuracy= 0.61719
# Iter 19200, Minibatch Loss= 8714.575195, Training Accuracy= 0.60938
# Iter 20480, Minibatch Loss= 10901.089844, Training Accuracy= 0.63281
# Iter 21760, Minibatch Loss= 12104.376953, Training Accuracy= 0.56250
# Iter 23040, Minibatch Loss= 11201.813477, Training Accuracy= 0.61719
# Iter 24320, Minibatch Loss= 11891.303711, Training Accuracy= 0.60156
# Iter 25600, Minibatch Loss= 8929.883789, Training Accuracy= 0.71094
# Iter 26880, Minibatch Loss= 10466.231445, Training Accuracy= 0.60938
# Iter 28160, Minibatch Loss= 10224.906250, Training Accuracy= 0.68750
# Iter 29440, Minibatch Loss= 11905.507812, Training Accuracy= 0.65625
# Iter 30720, Minibatch Loss= 13098.878906, Training Accuracy= 0.63281
# Iter 32000, Minibatch Loss= 9968.519531, Training Accuracy= 0.66406
# Iter 33280, Minibatch Loss= 9614.986328, Training Accuracy= 0.66406
# Iter 34560, Minibatch Loss= 11375.529297, Training Accuracy= 0.57812
# Iter 35840, Minibatch Loss= 8691.215820, Training Accuracy= 0.71875
# Iter 37120, Minibatch Loss= 9782.039062, Training Accuracy= 0.69531
# Iter 38400, Minibatch Loss= 9928.700195, Training Accuracy= 0.71875
# Iter 39680, Minibatch Loss= 9518.238281, Training Accuracy= 0.71094
# Iter 40960, Minibatch Loss= 9805.011719, Training Accuracy= 0.67188
# Iter 42240, Minibatch Loss= 12029.750000, Training Accuracy= 0.67969
# Iter 43520, Minibatch Loss= 6015.457031, Training Accuracy= 0.78125
# Iter 44800, Minibatch Loss= 8358.740234, Training Accuracy= 0.72656
# Iter 46080, Minibatch Loss= 8145.972656, Training Accuracy= 0.69531
# Iter 47360, Minibatch Loss= 9599.658203, Training Accuracy= 0.70312
# Iter 48640, Minibatch Loss= 9224.169922, Training Accuracy= 0.69531
# Iter 49920, Minibatch Loss= 9915.511719, Training Accuracy= 0.67969
# Iter 51200, Minibatch Loss= 7154.160156, Training Accuracy= 0.75000
# Iter 52480, Minibatch Loss= 9027.848633, Training Accuracy= 0.78125
# Iter 53760, Minibatch Loss= 8177.133301, Training Accuracy= 0.69531
# Iter 55040, Minibatch Loss= 7122.594727, Training Accuracy= 0.76562
# Iter 56320, Minibatch Loss= 5267.482910, Training Accuracy= 0.77344
# Iter 57600, Minibatch Loss= 9315.673828, Training Accuracy= 0.72656
# Iter 58880, Minibatch Loss= 6747.436035, Training Accuracy= 0.78125
# Iter 60160, Minibatch Loss= 7571.115234, Training Accuracy= 0.71875
# Iter 61440, Minibatch Loss= 8808.738281, Training Accuracy= 0.73438
# Iter 62720, Minibatch Loss= 7063.613770, Training Accuracy= 0.76562
# Iter 64000, Minibatch Loss= 6974.268555, Training Accuracy= 0.75000
# Iter 65280, Minibatch Loss= 7627.791504, Training Accuracy= 0.74219
# Iter 66560, Minibatch Loss= 7579.422363, Training Accuracy= 0.74219
# Iter 67840, Minibatch Loss= 6304.955078, Training Accuracy= 0.75781
# Iter 69120, Minibatch Loss= 9127.992188, Training Accuracy= 0.67969
# Iter 70400, Minibatch Loss= 6844.339355, Training Accuracy= 0.75781
# Iter 71680, Minibatch Loss= 9557.967773, Training Accuracy= 0.71094
# Iter 72960, Minibatch Loss= 9659.232422, Training Accuracy= 0.71094
# Iter 74240, Minibatch Loss= 6085.068848, Training Accuracy= 0.78125
# Iter 75520, Minibatch Loss= 7600.039062, Training Accuracy= 0.74219
# Iter 76800, Minibatch Loss= 8319.955078, Training Accuracy= 0.71875
# Iter 78080, Minibatch Loss= 9097.212891, Training Accuracy= 0.73438
# Iter 79360, Minibatch Loss= 8748.367188, Training Accuracy= 0.69531
# Iter 80640, Minibatch Loss= 5780.473145, Training Accuracy= 0.76562
# Iter 81920, Minibatch Loss= 9851.351562, Training Accuracy= 0.73438
# Iter 83200, Minibatch Loss= 10658.957031, Training Accuracy= 0.71094
# Iter 84480, Minibatch Loss= 5646.376953, Training Accuracy= 0.73438
# Iter 85760, Minibatch Loss= 7197.411621, Training Accuracy= 0.77344
# Iter 87040, Minibatch Loss= 10893.892578, Training Accuracy= 0.67188
# Iter 88320, Minibatch Loss= 8006.339844, Training Accuracy= 0.76562
# Iter 89600, Minibatch Loss= 8397.453125, Training Accuracy= 0.75781
# Iter 90880, Minibatch Loss= 8886.486328, Training Accuracy= 0.71094
# Iter 92160, Minibatch Loss= 9557.662109, Training Accuracy= 0.72656
# Iter 93440, Minibatch Loss= 8557.401367, Training Accuracy= 0.71875
# Iter 94720, Minibatch Loss= 8371.625000, Training Accuracy= 0.73438
# Iter 96000, Minibatch Loss= 7667.712891, Training Accuracy= 0.75000
# Iter 97280, Minibatch Loss= 11470.408203, Training Accuracy= 0.74219
# Iter 98560, Minibatch Loss= 7173.575195, Training Accuracy= 0.71094
# Iter 99840, Minibatch Loss= 7630.935547, Training Accuracy= 0.73438
# Optimization Finished!
# Testing Accuracy: 0.820312
